# %% [markdown]
# # Welcome to the `det` SQL Sandbox!
# In this notebook, we will explore our dummy database and learn how to spot bad data.

# %%
# This enables the %%sql magic commands
# %reload_ext sql

# Connect to our locally bootstrapped database
# %sql sqlite:///ecommerce.db
# Out:
# Connecting and switching to connection 'sqlite:///ecommerce.db'

# %%
# %%sql
# -- Let's see what our users look like!
# SELECT *
# FROM users
# LIMIT 5;
# Out:
# Running query in 'sqlite:///ecommerce.db'
# +---------+---------------------+---------+---------------------+
# | user_id |        email        | country |      created_at     |
# +---------+---------------------+---------+---------------------+
# |    1    |  alice@example.com  |    US   | 2026-01-01 10:00:00 |
# |    2    |   bob@example.com   |    CA   | 2026-01-02 11:30:00 |
# |    3    | charlie@example.com |    UK   | 2026-01-03 09:15:00 |
# |    4    |  alice@example.com  |    US   | 2026-01-04 14:00:00 |
# +---------+---------------------+---------+---------------------+

# %%
# %%sql
# -- Let's see what our orders look like!
# SELECT *
# FROM orders
# LIMIT 5;
# Out:
# Running query in 'sqlite:///ecommerce.db'
# +----------+---------+--------+-----------+---------------------+
# | order_id | user_id | amount |   status  |      order_date     |
# +----------+---------+--------+-----------+---------------------+
# |   101    |    1    | 150.5  | COMPLETED | 2026-01-05 12:00:00 |
# |   102    |    2    | -20.0  | COMPLETED | 2026-01-06 13:00:00 |
# |   103    |    3    |  75.0  |  PENDING  | 2026-01-07 14:22:00 |
# |   104    |    1    | 300.0  | COMPLETED | 2026-01-08 09:00:00 |
# |   105    |    3    |  25.0  |  PENDING  | 2026-02-07 14:22:00 |
# +----------+---------+--------+-----------+---------------------+
